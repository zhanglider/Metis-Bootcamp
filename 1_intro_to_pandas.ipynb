# %% [markdown]
# # Learning Pandas by Working with Weather Data

# %% [markdown]
# ## Introduction to Pandas

# %% [markdown]
# Pandas is a module in Python that is great for handling lots of data. We'll be relying on it today to help us sort, reshape, and clean up our data.
#
# > **From the Pandas documentation:**
# >
# > Here are just a few of the things that pandas does well:
# >
# > - Easy handling of **missing data** (represented as NaN) in floating point as well as non-floating point data
# - Size mutability: columns can be **inserted and deleted** from DataFrame and higher dimensional objects
# - Automatic and explicit **data alignment**: objects can be explicitly aligned to a set of labels, or the user can simply ignore the labels and let Series, DataFrame, etc. automatically align the data for you in computations
# - Powerful, flexible **group by** functionality to perform split-apply-combine operations on data sets, for both aggregating and transforming data
# - Make it **easy to convert** ragged, differently-indexed data in other Python and NumPy data structures into DataFrame objects
# - Intelligent **label-based slicing**, **fancy indexing**, and **subsetting** of large data sets
# - Intuitive **merging** and **joining** data sets
# - Flexible **reshaping** and **pivoting** of data sets
# - **Hierarchical labeling** of axes (possible to have multiple labels per tick)
# - **Robust IO tools** for loading data from flat files (CSV and delimited), Excel files, databases, and saving / loading data from the ultrafast HDF5 format
# - **Time series**-specific functionality: date range generation and frequency conversion, moving window statistics, moving window linear regressions, date shifting and lagging, etc.
#
# Let's get a sense of how it works with a test data set from a weather report.

# %%
import pandas as pd # the pd is by convention
import numpy as np # as is the np

import matplotlib.pyplot as plt
import seaborn as sns

# To Plot matplotlib figures inline on the notebook
# %matplotlib inline

# %% [markdown]
# The building blocks of pandas are called Series and DataFrames. A Dataframe is essentially a table, like shown below:

# %% [markdown]
# <img src='images/dataframe.png'>

# %% [markdown]
# Each row of the dataframe will be one specific record, and each column will be some aspect of that record. That will make more sense when we look at an example. Series are individual rows or columns (essentially if we break apart that dataframe into a single set of numbers). Let's look at that in action.

# %% [markdown]
# ### Reading Data
#
# To begin with, we're going to read in some data from a CSV.

# %%
weather = pd.read_csv('./data/weather.csv')
weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %% [markdown]
# Here we got our table, and it shows us that we're looking at the hourly weather at some point. We can see that the temperature was below freezing for each of the first four hours, that there was some fog, and that it was a little bit windy. We used `weather.head()` to show us just the first few rows. Otherwise, it would show us a HUGE data amount. We can look at the last few rows with `weather.tail()`

# %%
weather.tail()
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %% [markdown]
# Now let's use a Pandas built-in function to learn a little about our data.

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
# Date/Time             8784 non-null object
# Temp (C)              8784 non-null float64
# Dew Point Temp (C)    8784 non-null float64
# Rel Hum (%)           8784 non-null int64
# Wind Spd (km/h)       8784 non-null int64
# Visibility (km)       8784 non-null float64
# Stn Press (kPa)       8784 non-null float64
# Weather               8784 non-null object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# We can also look to see how much of our data makes sense by asking it to look at the numeric columns and give us some stats about them.

# %%
weather.describe()
# Out:
#           Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count  8784.000000         8784.000000  8784.000000      8784.000000
# mean      8.798144            2.555294    67.431694        14.945469
# std      11.687883           10.883072    16.918881         8.688696
# min     -23.300000          -28.500000    18.000000         0.000000
# 25%       0.100000           -5.900000    56.000000         9.000000
# 50%       9.300000            3.300000    68.000000        13.000000
# 75%      18.800000           11.800000    81.000000        20.000000
# max      33.000000           24.400000   100.000000        83.000000
#
#        Visibility (km)  Stn Press (kPa)
# count      8784.000000      8784.000000
# mean         27.664447       101.051623
# std          12.622688         0.844005
# min           0.200000        97.520000
# 25%          24.100000       100.560000
# 50%          25.000000       101.070000
# 75%          25.000000       101.590000
# max          48.300000       103.650000

# %%
weather.shape
# Out:
# (8784, 8)

# %% [markdown]
# Great, looks like these are all behaving relatively as expected! That's lovely.

# %% [markdown]
# ### Getting data from the dataframe
#
# Now let's learn how to grab some data from the DataFrame. Also, let's look at what a Series is. To start with, let's grab a column from our data (note that the head says, "hey just show me the first few rows of my dataframe or column or whatever I'm asking you for)

# %%
weather['Temp (C)'].head()
# Out:
# 0   -1.8
# 1   -1.8
# 2   -1.8
# 3   -1.5
# 4   -1.5
# Name: Temp (C), dtype: float64

# %% [markdown]
# This is a series! It has both the index (the left side) and the value. So we know which row it is and what the value is. That's pretty sweet. What can we do with a series? One really handy thing is getting the number of times a value shows up. Let's see that in action.

# %%
weather['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# Freezing Drizzle                              7
# Freezing Drizzle,Fog                          6
# Snow,Ice Pellets                              6
# Snow,Haze                                     5
# Snow Showers,Fog                              4
# Freezing Fog                                  4
# Freezing Rain,Fog                             4
# Moderate Snow                                 4
# Rain,Snow,Ice Pellets                         4
# Rain,Haze                                     3
# Thunderstorms,Rain                            3
# Thunderstorms,Rain Showers,Fog                3
# Freezing Drizzle,Haze                         3
# Thunderstorms                                 2
# Freezing Rain,Haze                            2
# Drizzle,Snow                                  2
# Moderate Snow,Blowing Snow                    2
# Rain Showers,Snow Showers                     2
# Freezing Rain,Snow Grains                     1
# Rain,Snow Grains                              1
# Snow Pellets                                  1
# Drizzle,Ice Pellets,Fog                       1
# Rain Showers,Fog                              1
# Thunderstorms,Moderate Rain Showers,Fog       1
# Thunderstorms,Rain,Fog                        1
# Rain,Ice Pellets                              1
# Thunderstorms,Heavy Rain Showers              1
# Freezing Rain,Ice Pellets,Fog                 1
# Rain,Snow,Fog                                 1
# Moderate Rain,Fog                             1
# Name: Weather, dtype: int64

# %% [markdown]
# **Exercise 1:**
#
# Using the dataframe, figure out what the most common Relative Humidity Percentage is

# %%
# Hint: Value Counts
weather['Rel Hum (%)'].value_counts()
#This is its own series, the numbers on the left become the index
# Out:
# 68     210
# 83     202
# 81     195
# 71     194
# 64     192
# 59     192
# 82     185
# 63     184
# 65     184
# 70     181
# 67     181
# 66     178
# 61     177
# 69     176
# 76     172
# 73     171
# 80     170
# 79     169
# 72     169
# 84     168
# 62     166
# 88     165
# 77     165
# 58     164
# 86     161
# 57     160
# 75     156
# 60     155
# 85     154
# 54     152
#       ...
# 94      66
# 43      63
# 40      63
# 96      59
# 95      59
# 38      56
# 39      53
# 34      52
# 37      51
# 36      50
# 35      47
# 99      44
# 33      42
# 98      35
# 31      29
# 29      26
# 30      26
# 32      25
# 27      24
# 28      22
# 26      18
# 24      13
# 100     10
# 21       9
# 25       9
# 22       6
# 23       5
# 20       5
# 18       2
# 19       1
# Name: Rel Hum (%), Length: 83, dtype: int64

# %% [markdown]
# ### Row Lookups

# %% [markdown]
# Cool. Now how do we access rows? We have to play a little bit of pandas games to do so. We'll use `.iloc` to do the job. Let's demonstrate by grabbing the first (0th) row.

# %%
weather.iloc[0]
# Out:
# Date/Time             2012-01-01 00:00:00
# Temp (C)                             -1.8
# Dew Point Temp (C)                   -3.9
# Rel Hum (%)                            86
# Wind Spd (km/h)                         4
# Visibility (km)                         8
# Stn Press (kPa)                    101.24
# Weather                               Fog
# Name: 0, dtype: object

# %% [markdown]
# We can get multiple rows by following Python's conventions like so:

# %%
weather.iloc[10:13]
# Out:
#               Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 10  2012-01-01 10:00:00      -1.0                -2.3           91
# 11  2012-01-01 11:00:00      -0.5                -2.1           89
# 12  2012-01-01 12:00:00      -0.2                -2.0           88
#
#     Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 10                9              1.2           101.15     Fog
# 11                7              4.0           100.98     Fog
# 12                9              4.8           100.79     Fog

# %% [markdown]
# We also might want to select multiple columns. We can do that like this:

# %%
weather[['Temp (C)',"Dew Point Temp (C)"]].head()
# Out:
#    Temp (C)  Dew Point Temp (C)
# 0      -1.8                -3.9
# 1      -1.8                -3.7
# 2      -1.8                -3.4
# 3      -1.5                -3.2
# 4      -1.5                -3.3

# %% [markdown]
# And what if we want to get rows and columns?

# %%
weather.loc[3:8, ['Temp (C)',"Dew Point Temp (C)"]]
#use LOC because the columns are being named
# Out:
#    Temp (C)  Dew Point Temp (C)
# 3      -1.5                -3.2
# 4      -1.5                -3.3
# 5      -1.4                -3.3
# 6      -1.5                -3.1
# 7      -1.4                -3.6
# 8      -1.4                -3.6

# %% [markdown]
# **Note that iloc and loc have slightly different outputs, we're not going to have time to fully explore the difference... just remember that they're slightly different! iloc means "index location" and loc means "label location"**.

# %%
weather.iloc[3:6]
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
# 5  2012-01-01 05:00:00      -1.4                -3.3           87
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
# 5                9              6.4           101.27                   Fog

# %%
weather.loc[3:6]
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
# 5  2012-01-01 05:00:00      -1.4                -3.3           87
# 6  2012-01-01 06:00:00      -1.5                -3.1           89
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
# 5                9              6.4           101.27                   Fog
# 6                7              6.4           101.29                   Fog

# %% [markdown]
# ### Filtering

# %% [markdown]
# What if we want to filter the data so we only see rows that match a certain criteria. We can do that by making a mask. A mask is a series that is trues and falses, based on some condition. So let's ask it to check if the temperature was -1.8, and if so mark the row as a true and if not, mark it as a false.

# %%
mask = (weather['Temp (C)'] == -1.8) 
mask.head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Temp (C), dtype: bool

# %%
weather['Temp (C)'].head()
# Out:
# 0   -1.8
# 1   -1.8
# 2   -1.8
# 3   -1.5
# 4   -1.5
# Name: Temp (C), dtype: float64

# %% [markdown]
# Now we apply the mask and should see that only rows with that temperature remain!

# %%
weather_test = weather[mask] 
weather_test.head(10)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 164   2012-01-07 20:00:00      -1.8                -3.7           87
# 682   2012-01-29 10:00:00      -1.8                -8.3           61
# 927   2012-02-08 15:00:00      -1.8               -12.8           43
# 1081  2012-02-15 01:00:00      -1.8                -5.2           78
# 1216  2012-02-20 16:00:00      -1.8                -8.5           60
# 1298  2012-02-24 02:00:00      -1.8                -5.4           76
# 1328  2012-02-25 08:00:00      -1.8                -3.2           90
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                   4              8.0           101.24                   Fog
# 1                   4              8.0           101.24                   Fog
# 2                   7              4.0           101.26  Freezing Drizzle,Fog
# 164                 4              9.7           100.48                  Snow
# 682                24             24.1           100.87         Mostly Cloudy
# 927                32             48.3           101.45          Mainly Clear
# 1081                4             25.0           101.31                Cloudy
# 1216               20             48.3           102.06          Mainly Clear
# 1298                0             25.0           100.20                 Clear
# 1328               32              1.2            98.20     Snow,Blowing Snow

# %% [markdown]
# What if we want to match multiple conditions? Let's do a double filter

# %%
mask = (weather['Temp (C)'] == -1.8) & (weather['Visibility (km)'] == 8.0)
weather[mask]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 7778  2012-11-20 02:00:00      -1.8                -3.5           88
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 0                   4              8.0           101.24     Fog
# 1                   4              8.0           101.24     Fog
# 7778                6              8.0           102.08     Fog

# %%
mask.value_counts()
# Out:
# False    8781
# True        3
# dtype: int64

# %% [markdown]
# **Exercise 2:**
#
# Apply a new filter to select only the days where the temperature is above 25C and the humidity is at or above 80%. How many hours are like this?

# %%
# Hint: create a filter called mask, then apply it to the dataframe
mask = (weather['Temp (C)'] > 25) & (weather['Rel Hum (%)'] >= 80)
weather[mask]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 4766  2012-07-17 14:00:00      25.5                23.1           87
# 4767  2012-07-17 15:00:00      25.8                22.0           80
# 4769  2012-07-17 17:00:00      25.9                22.2           80
# 5221  2012-08-05 13:00:00      25.2                23.0           88
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# 4766               17              6.4            99.65
# 4767                4             24.1            99.69
# 4769                7             24.1            99.83
# 5221               24             12.9           100.40
#
#                          Weather
# 4766  Thunderstorms,Rain Showers
# 4767                      Cloudy
# 4769                      Cloudy
# 5221                Rain Showers

# %% [markdown]
# ### Doing Stats with Pandas

# %% [markdown]
# Pandas also let's us do some neat things like measuring some statistics about our data. Let's take a look at the average temperature throughout the year of data.

# %%
weather['Temp (C)'].mean()
# Out:
# 8.79814435336981

# %% [markdown]
# Or we could find the max or min temperature

# %%
weather['Temp (C)'].max()
# Out:
# 33.0

# %%
weather['Temp (C)'].min()
# Out:
# -23.3

# %% [markdown]
# **Exercise 3:**
#
# Let's combine filtering and stats. Find the average wind speed on days that are less than 10C.

# %%
# Hint: Create the filter, apply it to the frame, then calculate something on the new dataframe
mask = (weather['Temp (C)'] < 10)
weather2 = weather[mask]
weather2['Wind Spd (km/h)'].mean()
# Out:
# 15.734191258043044

# %% [markdown]
# ### Making new columns

# %% [markdown]
# Pandas also allows us to create columns that are mixtures of other columns. Let's make a column that is "visibility as a percentage of the maximum visibility".

# %%
max_vis = weather['Visibility (km)'].max()
weather['percent_visibility'] = weather['Visibility (km)']/max_vis
weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    percent_visibility
# 0            0.165631
# 1            0.165631
# 2            0.082816
# 3            0.082816
# 4            0.099379

# %% [markdown]
# **Exercise 4**
#
# Let's convert temperature to Farenheit and create a new column to store that. The conversion to degrees F is done by multiplying the temperature in C by 1.8, then adding 32. Store this in a column called `Temp (F)`. If you've done it right, the first conversion should go from `-1.8C` to `28.76F` in a new column.

# %%
# Hint: You can multiply a column by a number, and add numbers to it
weather['Temp (F)'] = weather['Temp (C)']*1.8+32
weather
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# 5     2012-01-01 05:00:00      -1.4                -3.3           87
# 6     2012-01-01 06:00:00      -1.5                -3.1           89
# 7     2012-01-01 07:00:00      -1.4                -3.6           85
# 8     2012-01-01 08:00:00      -1.4                -3.6           85
# 9     2012-01-01 09:00:00      -1.3                -3.1           88
# 10    2012-01-01 10:00:00      -1.0                -2.3           91
# 11    2012-01-01 11:00:00      -0.5                -2.1           89
# 12    2012-01-01 12:00:00      -0.2                -2.0           88
# 13    2012-01-01 13:00:00       0.2                -1.7           87
# 14    2012-01-01 14:00:00       0.8                -1.1           87
# 15    2012-01-01 15:00:00       1.8                -0.4           85
# 16    2012-01-01 16:00:00       2.6                -0.2           82
# 17    2012-01-01 17:00:00       3.0                 0.0           81
# 18    2012-01-01 18:00:00       3.8                 1.0           82
# 19    2012-01-01 19:00:00       3.1                 1.3           88
# 20    2012-01-01 20:00:00       3.2                 1.3           87
# 21    2012-01-01 21:00:00       4.0                 1.7           85
# 22    2012-01-01 22:00:00       4.4                 1.9           84
# 23    2012-01-01 23:00:00       5.3                 2.0           79
# 24    2012-01-02 00:00:00       5.2                 1.5           77
# 25    2012-01-02 01:00:00       4.6                 0.0           72
# 26    2012-01-02 02:00:00       3.9                -0.9           71
# 27    2012-01-02 03:00:00       3.7                -1.5           69
# 28    2012-01-02 04:00:00       2.9                -2.3           69
# 29    2012-01-02 05:00:00       2.6                -2.3           70
# ...                   ...       ...                 ...          ...
# 8754  2012-12-30 18:00:00     -12.6               -16.0           76
# 8755  2012-12-30 19:00:00     -13.4               -16.5           77
# 8756  2012-12-30 20:00:00     -13.8               -16.5           80
# 8757  2012-12-30 21:00:00     -13.8               -16.5           80
# 8758  2012-12-30 22:00:00     -13.7               -16.3           81
# 8759  2012-12-30 23:00:00     -12.1               -15.1           78
# 8760  2012-12-31 00:00:00     -11.1               -14.4           77
# 8761  2012-12-31 01:00:00     -10.7               -14.0           77
# 8762  2012-12-31 02:00:00     -10.1               -13.4           77
# 8763  2012-12-31 03:00:00     -11.8               -14.4           81
# 8764  2012-12-31 04:00:00     -10.5               -12.8           83
# 8765  2012-12-31 05:00:00     -10.2               -12.4           84
# 8766  2012-12-31 06:00:00      -9.7               -11.7           85
# 8767  2012-12-31 07:00:00      -9.3               -11.3           85
# 8768  2012-12-31 08:00:00      -8.6               -10.3           87
# 8769  2012-12-31 09:00:00      -8.1                -9.6           89
# 8770  2012-12-31 10:00:00      -7.4                -8.9           89
# 8771  2012-12-31 11:00:00      -6.7                -7.9           91
# 8772  2012-12-31 12:00:00      -5.8                -7.5           88
# 8773  2012-12-31 13:00:00      -4.6                -6.6           86
# 8774  2012-12-31 14:00:00      -3.4                -5.7           84
# 8775  2012-12-31 15:00:00      -2.3                -4.6           84
# 8776  2012-12-31 16:00:00      -1.4                -4.0           82
# 8777  2012-12-31 17:00:00      -1.1                -3.3           85
# 8778  2012-12-31 18:00:00      -1.3                -3.1           88
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                   4              8.0           101.24                   Fog
# 1                   4              8.0           101.24                   Fog
# 2                   7              4.0           101.26  Freezing Drizzle,Fog
# 3                   6              4.0           101.27  Freezing Drizzle,Fog
# 4                   7              4.8           101.23                   Fog
# 5                   9              6.4           101.27                   Fog
# 6                   7              6.4           101.29                   Fog
# 7                   7              8.0           101.26                   Fog
# 8                   9              8.0           101.23                   Fog
# 9                  15              4.0           101.20                   Fog
# 10                  9              1.2           101.15                   Fog
# 11                  7              4.0           100.98                   Fog
# 12                  9              4.8           100.79                   Fog
# 13                 13              4.8           100.58                   Fog
# 14                 20              4.8           100.31                   Fog
# 15                 22              6.4           100.07                   Fog
# 16                 13             12.9            99.93         Mostly Cloudy
# 17                 13             16.1            99.81                Cloudy
# 18                 15             12.9            99.74                  Rain
# 19                 15             12.9            99.68                  Rain
# 20                 19             25.0            99.50                Cloudy
# 21                 20             25.0            99.39                Cloudy
# 22                 24             19.3            99.32          Rain Showers
# 23                 30             25.0            99.31                Cloudy
# 24                 35             25.0            99.26          Rain Showers
# 25                 39             25.0            99.26                Cloudy
# 26                 32             25.0            99.26         Mostly Cloudy
# 27                 33             25.0            99.30         Mostly Cloudy
# 28                 32             25.0            99.26         Mostly Cloudy
# 29                 32             25.0            99.21         Mostly Cloudy
# ...               ...              ...              ...                   ...
# 8754               24             25.0           101.36          Mainly Clear
# 8755               26             25.0           101.47          Mainly Clear
# 8756               24             25.0           101.52                 Clear
# 8757               20             25.0           101.50          Mainly Clear
# 8758               19             25.0           101.54          Mainly Clear
# 8759               28             25.0           101.52         Mostly Cloudy
# 8760               26             25.0           101.51                Cloudy
# 8761               15             25.0           101.50                Cloudy
# 8762                9             25.0           101.45                Cloudy
# 8763                6             25.0           101.42         Mostly Cloudy
# 8764               11             25.0           101.34                Cloudy
# 8765                6             25.0           101.28                Cloudy
# 8766                4             25.0           101.23                Cloudy
# 8767                0             19.3           101.19          Snow Showers
# 8768                4              3.2           101.14          Snow Showers
# 8769                4              2.4           101.09                  Snow
# 8770                4              6.4           101.05              Snow,Fog
# 8771                9              9.7           100.93                  Snow
# 8772                4             12.9           100.78                  Snow
# 8773                4             12.9           100.63                  Snow
# 8774                6             11.3           100.57                  Snow
# 8775                9              9.7           100.47                  Snow
# 8776               13             12.9           100.40                  Snow
# 8777               19              9.7           100.30                  Snow
# 8778               17              9.7           100.19                  Snow
# 8779               30              9.7           100.13                  Snow
# 8780               24              9.7           100.03                  Snow
# 8781               28              4.8            99.95                  Snow
# 8782               28              9.7            99.91                  Snow
# 8783               30             11.3            99.89                  Snow
#
#       percent_visibility  Temp (F)
# 0               0.165631     28.76
# 1               0.165631     28.76
# 2               0.082816     28.76
# 3               0.082816     29.30
# 4               0.099379     29.30
# 5               0.132505     29.48
# 6               0.132505     29.30
# 7               0.165631     29.48
# 8               0.165631     29.48
# 9               0.082816     29.66
# 10              0.024845     30.20
# 11              0.082816     31.10
# 12              0.099379     31.64
# 13              0.099379     32.36
# 14              0.099379     33.44
# 15              0.132505     35.24
# 16              0.267081     36.68
# 17              0.333333     37.40
# 18              0.267081     38.84
# 19              0.267081     37.58
# 20              0.517598     37.76
# 21              0.517598     39.20
# 22              0.399586     39.92
# 23              0.517598     41.54
# 24              0.517598     41.36
# 25              0.517598     40.28
# 26              0.517598     39.02
# 27              0.517598     38.66
# 28              0.517598     37.22
# 29              0.517598     36.68
# ...                  ...       ...
# 8754            0.517598      9.32
# 8755            0.517598      7.88
# 8756            0.517598      7.16
# 8757            0.517598      7.16
# 8758            0.517598      7.34
# 8759            0.517598     10.22
# 8760            0.517598     12.02
# 8761            0.517598     12.74
# 8762            0.517598     13.82
# 8763            0.517598     10.76
# 8764            0.517598     13.10
# 8765            0.517598     13.64
# 8766            0.517598     14.54
# 8767            0.399586     15.26
# 8768            0.066253     16.52
# 8769            0.049689     17.42
# 8770            0.132505     18.68
# 8771            0.200828     19.94
# 8772            0.267081     21.56
# 8773            0.267081     23.72
# 8774            0.233954     25.88
# 8775            0.200828     27.86
# 8776            0.267081     29.48
# 8777            0.200828     30.02
# 8778            0.200828     29.66
# 8779            0.200828     32.18
# 8780            0.200828     32.36
# 8781            0.099379     31.10
# 8782            0.200828     31.64
# 8783            0.233954     32.00
#
# [8784 rows x 10 columns]

# %% [markdown]
# ### Plotting with Pandas

# %% [markdown]
# The last part of pandas we want to explore today is some of it's built in plotting features. Let's plot a histogram of temperature over the year.

# %%
weather['Temp (C)'].plot.hist()
plt.xlabel("Temperature (C)");

# %% [markdown]
# What about weather over time? Let's do a line plot of the temperature.

# %%
weather['Temp (C)'].plot.line()

# %% [markdown]
# Neat! Except, that doesn't show us the date on the X-Axis. That's because right now, we don't have the date as the index. Let's try to fix that.

# %%
weather['Date/Time'] = pd.to_datetime(weather['Date/Time'])
weather = weather.set_index('Date/Time')

# %%
weather['Temp (C)'].plot.line()

# %% [markdown]
# **Exercise 5**
#
# Plot a histogram of wind speeds. Also plot the wind speed versus the time.

# %%
# Hint: plot.hist(), plot.line()

# %%
weather['Wind Spd (km/h)'].plot.hist()
plt.xlabel("Wind Speed (km/h)");

# %%
weather['Wind Spd (km/h)'].plot.line()

# %% [markdown]
# ## Exercises

# %% [markdown]
# In the data folder, there is a csv that contains the file `auto-mpg.csv`. That data is from here: https://archive.ics.uci.edu/ml/datasets/auto+mpg
#
# This contains information about makes/models of cars and their reported fuel efficiency. We'll use that as a baseline for some hands on work with Pandas.

# %% [markdown]
# ### Challenge 1: Load the file into a Pandas dataframe, then print the top 5 rows
#
# Store this dataframe in a variable called `autos`

# %%
autos = pd.read_csv('./data/auto-mpg.csv')
autos.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year  origin                   car_name
# 0          70       1  chevrolet,chevelle,malibu
# 1          70       1          buick,skylark,320
# 2          70       1         plymouth,satellite
# 3          70       1              amc,rebel,sst
# 4          70       1                ford,torino

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
# mpg             392 non-null float64
# cylinders       392 non-null int64
# displacement    392 non-null float64
# horsepower      392 non-null float64
# weight          392 non-null int64
# acceleration    392 non-null float64
# model_year      392 non-null int64
# origin          392 non-null int64
# car_name        392 non-null object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 27.6+ KB

# %%
autos.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %% [markdown]
# ### Challenge 2: Find the mean weight and the mean mpg in the dataset as a whole. Now find those for all vehicles with model_year equal to 77

# %%
autos['mpg'].mean()
# Out:
# 23.44591836734694

# %%
autos['weight'].mean()
# Out:
# 2977.5841836734694

# %%
mask = (autos['model_year'] == 77) 
autos[mask]
autos2 = autos[mask]
autos2
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 214  31.5          4          98.0        68.0    2045          18.5
# 215  30.0          4         111.0        80.0    2155          14.8
# 216  36.0          4          79.0        58.0    1825          18.6
# 217  25.5          4         122.0        96.0    2300          15.5
# 218  33.5          4          85.0        70.0    1945          16.8
# 219  17.5          8         305.0       145.0    3880          12.5
# 220  17.0          8         260.0       110.0    4060          19.0
# 221  15.5          8         318.0       145.0    4140          13.7
# 222  15.0          8         302.0       130.0    4295          14.9
# 223  17.5          6         250.0       110.0    3520          16.4
# 224  20.5          6         231.0       105.0    3425          16.9
# 225  19.0          6         225.0       100.0    3630          17.7
# 226  18.5          6         250.0        98.0    3525          19.0
# 227  16.0          8         400.0       180.0    4220          11.1
# 228  15.5          8         350.0       170.0    4165          11.4
# 229  15.5          8         400.0       190.0    4325          12.2
# 230  16.0          8         351.0       149.0    4335          14.5
# 231  29.0          4          97.0        78.0    1940          14.5
# 232  24.5          4         151.0        88.0    2740          16.0
# 233  26.0          4          97.0        75.0    2265          18.2
# 234  25.5          4         140.0        89.0    2755          15.8
# 235  30.5          4          98.0        63.0    2051          17.0
# 236  33.5          4          98.0        83.0    2075          15.9
# 237  30.0          4          97.0        67.0    1985          16.4
# 238  30.5          4          97.0        78.0    2190          14.1
# 239  22.0          6         146.0        97.0    2815          14.5
# 240  21.5          4         121.0       110.0    2600          12.8
# 241  21.5          3          80.0       110.0    2720          13.5
#
#      model_year  origin                      car_name
# 214          77       3             honda,accord,cvcc
# 215          77       1       buick,opel,isuzu,deluxe
# 216          77       2                 renault,5,gtl
# 217          77       1             plymouth,arrow,gs
# 218          77       3         datsun,f-10,hatchback
# 219          77       1     chevrolet,caprice,classic
# 220          77       1    oldsmobile,cutlass,supreme
# 221          77       1         dodge,monaco,brougham
# 222          77       1       mercury,cougar,brougham
# 223          77       1            chevrolet,concours
# 224          77       1                 buick,skylark
# 225          77       1        plymouth,volare,custom
# 226          77       1                  ford,granada
# 227          77       1         pontiac,grand,prix,lj
# 228          77       1  chevrolet,monte,carlo,landau
# 229          77       1              chrysler,cordoba
# 230          77       1              ford,thunderbird
# 231          77       2      volkswagen,rabbit,custom
# 232          77       1         pontiac,sunbird,coupe
# 233          77       3       toyota,corolla,liftback
# 234          77       1           ford,mustang,ii,2+2
# 235          77       1            chevrolet,chevette
# 236          77       1                dodge,colt,m/m
# 237          77       3                     subaru,dl
# 238          77       2             volkswagen,dasher
# 239          77       3                    datsun,810
# 240          77       2                      bmw,320i
# 241          77       3                    mazda,rx-4

# %%
autos2[['mpg','weight']].mean()
# Out:
# mpg         23.375000
# weight    2997.357143
# dtype: float64

# %%
autos2['weight'].mean()
# Out:
# 2997.3571428571427

# %% [markdown]
# ### Challenge 3: Create a column that is horsepower per cylinder

# %%
autos['hp_per_cylinder'] = autos['horsepower']/autos['cylinders']
autos
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# 13   14.0          8         455.0       225.0    3086          10.0
# 14   24.0          4         113.0        95.0    2372          15.0
# 15   22.0          6         198.0        95.0    2833          15.5
# 16   18.0          6         199.0        97.0    2774          15.5
# 17   21.0          6         200.0        85.0    2587          16.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# 22   25.0          4         104.0        95.0    2375          17.5
# 23   26.0          4         121.0       113.0    2234          12.5
# 24   21.0          6         199.0        90.0    2648          15.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 27   11.0          8         318.0       210.0    4382          13.5
# 28    9.0          8         304.0       193.0    4732          18.5
# 29   27.0          4          97.0        88.0    2130          14.5
# ..    ...        ...           ...         ...     ...           ...
# 362  28.0          4         112.0        88.0    2605          19.6
# 363  27.0          4         112.0        88.0    2640          18.6
# 364  34.0          4         112.0        88.0    2395          18.0
# 365  31.0          4         112.0        85.0    2575          16.2
# 366  29.0          4         135.0        84.0    2525          16.0
# 367  27.0          4         151.0        90.0    2735          18.0
# 368  24.0          4         140.0        92.0    2865          16.4
# 369  36.0          4         105.0        74.0    1980          15.3
# 370  37.0          4          91.0        68.0    2025          18.2
# 371  31.0          4          91.0        68.0    1970          17.6
# 372  38.0          4         105.0        63.0    2125          14.7
# 373  36.0          4          98.0        70.0    2125          17.3
# 374  36.0          4         120.0        88.0    2160          14.5
# 375  36.0          4         107.0        75.0    2205          14.5
# 376  34.0          4         108.0        70.0    2245          16.9
# 377  38.0          4          91.0        67.0    1965          15.0
# 378  32.0          4          91.0        67.0    1965          15.7
# 379  38.0          4          91.0        67.0    1995          16.2
# 380  25.0          6         181.0       110.0    2945          16.4
# 381  38.0          6         262.0        85.0    3015          17.0
# 382  26.0          4         156.0        92.0    2585          14.5
# 383  22.0          6         232.0       112.0    2835          14.7
# 384  32.0          4         144.0        96.0    2665          13.9
# 385  36.0          4         135.0        84.0    2370          13.0
# 386  27.0          4         151.0        90.0    2950          17.3
# 387  27.0          4         140.0        86.0    2790          15.6
# 388  44.0          4          97.0        52.0    2130          24.6
# 389  32.0          4         135.0        84.0    2295          11.6
# 390  28.0          4         120.0        79.0    2625          18.6
# 391  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                           car_name  hp_per_cylinder
# 0            70       1          chevrolet,chevelle,malibu        16.250000
# 1            70       1                  buick,skylark,320        20.625000
# 2            70       1                 plymouth,satellite        18.750000
# 3            70       1                      amc,rebel,sst        18.750000
# 4            70       1                        ford,torino        17.500000
# 5            70       1                   ford,galaxie,500        24.750000
# 6            70       1                   chevrolet,impala        27.500000
# 7            70       1                  plymouth,fury,iii        26.875000
# 8            70       1                   pontiac,catalina        28.125000
# 9            70       1                 amc,ambassador,dpl        23.750000
# 10           70       1                dodge,challenger,se        21.250000
# 11           70       1                 plymouth,'cuda,340        20.000000
# 12           70       1              chevrolet,monte,carlo        18.750000
# 13           70       1            buick,estate,wagon,(sw)        28.125000
# 14           70       3              toyota,corona,mark,ii        23.750000
# 15           70       1                    plymouth,duster        15.833333
# 16           70       1                         amc,hornet        16.166667
# 17           70       1                      ford,maverick        14.166667
# 18           70       3                       datsun,pl510        22.000000
# 19           70       2       volkswagen,1131,deluxe,sedan        11.500000
# 20           70       2                        peugeot,504        21.750000
# 21           70       2                        audi,100,ls        22.500000
# 22           70       2                           saab,99e        23.750000
# 23           70       2                           bmw,2002        28.250000
# 24           70       1                        amc,gremlin        15.000000
# 25           70       1                          ford,f250        26.875000
# 26           70       1                          chevy,c20        25.000000
# 27           70       1                         dodge,d200        26.250000
# 28           70       1                           hi,1200d        24.125000
# 29           71       3                       datsun,pl510        22.000000
# ..          ...     ...                                ...              ...
# 362          82       1                 chevrolet,cavalier        22.000000
# 363          82       1           chevrolet,cavalier,wagon        22.000000
# 364          82       1          chevrolet,cavalier,2-door        22.000000
# 365          82       1         pontiac,j2000,se,hatchback        21.250000
# 366          82       1                     dodge,aries,se        21.000000
# 367          82       1                    pontiac,phoenix        22.500000
# 368          82       1               ford,fairmont,futura        23.000000
# 369          82       2                volkswagen,rabbit,l        18.500000
# 370          82       3                 mazda,glc,custom,l        17.000000
# 371          82       3                   mazda,glc,custom        17.000000
# 372          82       1             plymouth,horizon,miser        15.750000
# 373          82       1                     mercury,lynx,l        17.500000
# 374          82       3                   nissan,stanza,xe        22.000000
# 375          82       3                       honda,accord        18.750000
# 376          82       3                     toyota,corolla        17.500000
# 377          82       3                        honda,civic        16.750000
# 378          82       3                 honda,civic,(auto)        16.750000
# 379          82       3                      datsun,310,gx        16.750000
# 380          82       1              buick,century,limited        18.333333
# 381          82       1  oldsmobile,cutlass,ciera,(diesel)        14.166667
# 382          82       1         chrysler,lebaron,medallion        23.000000
# 383          82       1                     ford,granada,l        18.666667
# 384          82       3                   toyota,celica,gt        24.000000
# 385          82       1                  dodge,charger,2.2        21.000000
# 386          82       1                   chevrolet,camaro        22.500000
# 387          82       1                    ford,mustang,gl        21.500000
# 388          82       2                          vw,pickup        13.000000
# 389          82       1                      dodge,rampage        21.000000
# 390          82       1                        ford,ranger        19.750000
# 391          82       1                         chevy,s-10        20.500000
#
# [392 rows x 10 columns]

# %% [markdown]
# ### Challenge 4: Make two histograms, one of hp_per_cylinder and one of horsepower.

# %%
autos['hp_per_cylinder'].plot.hist()
plt.xlabel("Horsepower per Cylinder");

# %%
autos['horsepower'].plot.hist()
plt.xlabel("Horsepower");
